# %%
import os
from ossapi import Ossapi
import sqlite3
from time import strftime, localtime
import time
from concurrent.futures import ThreadPoolExecutor
import sys
from numpy import array_split
import pickle
from datetime import datetime
sys.path.insert(0, "../") # Required for database in different directory. 

OSU_CLIENT_ID = os.environ.get('OSU_CLIENT_ID')
OSU_CLIENT_SECRET = os.environ.get('OSU_CLIENT_SECRET')

api = Ossapi(OSU_CLIENT_ID, OSU_CLIENT_SECRET)

with open("leaderboard_ids.pickle", "rb") as handle:
    leaderboard_ids = pickle.load(handle)
leaderboard_ids = set(leaderboard_ids)

top_or_recent = "recent"
mode = "std"

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 eggtofu = api.score('osu', 1742868886)
#
# File ~/osu_oracle/osu_oracle_venv/lib/python3.10/site-packages/ossapi/ossapiv2.py:211, in request.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208     if id_:
#     209         kwargs[arg_name] = id_
# --> 211 return function(*args, **kwargs)
#
# File ~/osu_oracle/osu_oracle_venv/lib/python3.10/site-packages/ossapi/ossapiv2.py:2376, in Ossapi.score(self, mode, score_id)
#    2356 @request(Scope.PUBLIC, category="scores")
#    2357 def score(self,
#    2358     mode: GameModeT,
#    2359     score_id: int
#    2360 ) -> Score:
#    2361     """
#    2362     Get a score.
#    2363
#    (...)
#    2374     <https://osu.ppy.sh/docs/index.html#scoresmodescore>`__ endpoint.
#    2375     """
# -> 2376     return self._get(Score, f"/scores/{mode.value}/{score_id}")
#
# File ~/osu_oracle/osu_oracle_venv/lib/python3.10/site-packages/ossapi/ossapiv2.py:675, in Ossapi._get(self, type_, url, params)
#     674 def _get(self, type_, url, params={}):
# --> 675     return self._request(type_, "GET", url, params=params)
#
# File ~/osu_oracle/osu_oracle_venv/lib/python3.10/site-packages/ossapi/ossapiv2.py:654, in Ossapi._request(self, type_, method, url, params, data)
#     651     json_ = r.json()
#     653 self.log.debug(f"received json: \n{json.dumps(json_, indent=4)}")
# --> 654 self._check_response(json_, r.url)
#     656 return self._instantiate_type(type_, json_)
#
# File ~/osu_oracle/osu_oracle_venv/lib/python3.10/site-packages/ossapi/ossapiv2.py:663, in Ossapi._check_response(self, json_, url)
#     658 def _check_response(self, json_, url):
#     659     # TODO this should just be `if "error" in json`, but for some reason
#     660     # `self.search_beatmaps` always returns an error in the response...
#     661     # open an issue on osu-web?
#     662     if len(json_) == 1 and "error" in json_:
# --> 663         raise ValueError(f"api returned an error of `{json_['error']}` for "
#     664             f"a request to {unquote(url)}")
#     666     # some endpoints only require authorization grant for some endpoints.
#     667     # e.g. normally api.match only requires client credentials grant, but for
#     668     # private matches like api.match(111632899), it will return this error.
#     669     if json_ == {"authentication": "basic"}:
#
# ValueError: api returned an error of `Specified Solo\Score couldn't be found.` for a request to https://osu.ppy.sh/api/v2/scores/osu/1742868886

# %%
eggtofu.version
# Out:
# 'Insane'

# %%
num_done = 0
last_time = time.time()

def scrape_users(ids):
    """
    Adds user data to users table and scores to scores in ../data/UserScores.db after scraping.
    ids: list of ids to scrape
    """
    global num_done
    global last_time
    conn = sqlite3.connect("../data/UserScores.db")  
    cursor = conn.cursor()
    try:
        for user_id in ids:
            try:
                top_scores = api.user_scores(user_id, type="recent", mode="osu", limit=100)
                scores = []
            except Exception as e:
                print(e)
                continue

            for score in top_scores:
                try:
                    beatmap = getattr(score, "beatmap", None)
                    beatmap_id = getattr(beatmap, "id", None) if beatmap else None
                    
                    beatmapset_id = getattr(beatmap, "beatmapset_id", None) if beatmap else None

                    mods = getattr(score, "mods", None)
                    mods = getattr(mods, "value", None) if mods else None

                    pp = getattr(score, "pp", None)

                    created_at = getattr(score, "created_at", None)
                    created_at = (
                        datetime.strftime(created_at, "%Y-%m-%d %H:%M:%S")
                        if created_at
                        else None
                    )

                    score = (
                        int(user_id),
                        beatmap_id,
                        beatmapset_id,
                        pp,
                        mods,
                        created_at,
                    )
                    scores.append(score)

                except Exception as e:
                    print(e)
                    continue

            try:
                cursor.executemany(
                    f"""
                    INSERT INTO {top_or_recent}_scores_{mode} (user_id, beatmap_id, beatmapset_id, pp, mods, created_at)
                    VALUES (?, ?, ?, ?, ?, ?)
                    """,
                    scores,
                )
                conn.commit()
            except Exception as e:
                print(e)
                continue

            num_done += 1
            if num_done % 100 == 0:
                print(
                    str(num_done) + ": " + str(time.time() - last_time),
                    strftime("%H:%M:%S", localtime(time.time())),
                )
                last_time = time.time()
                
    except Exception as e:
        print(e)
    finally:
        conn.close()

# %%
conn = sqlite3.connect('../data/UserScores.db')
cursor = conn.cursor()


completed_user_ids = cursor.execute(f"SELECT DISTINCT user_id FROM {top_or_recent}_scores_{mode}").fetchall()
completed_user_ids = set([x[0] for x in completed_user_ids])
conn.close()

remaining_ids = list(leaderboard_ids - completed_user_ids)
print(f"Remaining user ids to scrape: {len(remaining_ids)}")

num_partitions = 5
partitioned_user_ids = array_split(remaining_ids, num_partitions)

for user_ids in partitioned_user_ids:
    print(len(user_ids))

with ThreadPoolExecutor(max_workers=num_partitions) as executor:
    for user_ids in partitioned_user_ids:
        executor.submit(scrape_users, user_ids)
# Out:
# Remaining user ids to scrape: 663332
# 132667
# 132667
# 132666
# 132666
# 132666
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/19283604/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/10054109/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/7521530/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/15910145/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/12151369/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/10485990/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/257/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/14680369/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/12151573/scores/recent?mode=osu&limit=100
# 673: 7.643176078796387 18:37:29
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/6292007/scores/recent?mode=osu&limit=100
# 707: 2.2301619052886963 18:37:32
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/8798014/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/20104537/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/15910280/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/13813134/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/19283856/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/2506715/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/11716016/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/23478234/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/1230260/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/10895326/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15910326/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/18007479/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12992482/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/8798180/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/13813177/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/8798181/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15910331/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/409574/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/18007484/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/31866853/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/20104645/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/4603880/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/11716039/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15089641/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/1230280/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/17186793/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/28493256/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/6701047/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/5424586/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15089655/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/11716047/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/2506745/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7521746/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/25575419/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/11716064/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/4603900/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/32687584/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/10895357/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/18007531/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12992510/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9618924/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/2506751/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/20104692/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12992513/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/10895367/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7521781/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/29769735/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/11716091/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/6701066/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/11716096/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/19283979/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15910401/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/2506765/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/22201858/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/19283992/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/24299011/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/4603929/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/22201861/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/21381148/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/5424648/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/8798237/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9618952/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/19284001/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7521804/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/4603941/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/11716111/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/17186853/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7521814/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/6701095/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/20104726/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/6701104/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/25575472/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/13813273/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/19284016/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9618973/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/4603961/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/24299037/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/5424671/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/10895422/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/13813279/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/2506816/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/3327529/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12992576/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/3327530/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/21381188/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9618985/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12992586/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9618992/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/10895434/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/22201908/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/25575503/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/1230389/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/19284048/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/5424700/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/8798287/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/28493375/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/6701144/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7521856/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12992600/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/20104771/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/2506845/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9619022/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/29769824/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/5424725/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/6701155/scores/recent?mode=osu&limit=100
# 777: 8.976811408996582 18:37:41
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15910488/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/23478371/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/16345912/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15910494/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/21381219/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7957309/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/11716191/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/2506854/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/5860161/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12992612/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/20104807/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12151622/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/29769834/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15910504/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/16345927/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/2506859/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/22201961/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7957321/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/23478381/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/20104811/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7957326/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/6701166/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/30590578/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/14248784/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/409711/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/5424756/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/10054483/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/23478386/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7521910/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/26831699/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/21381242/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/20104822/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12151637/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15089797/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15910522/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/18443092/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12992648/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/31026004/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15910528/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/8798353/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9619075/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/20540248/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/409747/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/1665881/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/3327626/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/8798358/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/16345954/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7521934/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/6701207/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/3763044/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/3327632/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/8798359/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/35220327/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/20104852/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/19284120/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/3763051/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/13813400/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15089817/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/14248816/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9619097/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/19284121/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/1665910/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15910554/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/6701216/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/22637435/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/17186976/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7957373/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15910555/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/10895521/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/10054534/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/26396315/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12992676/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/16345992/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7521951/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/17186982/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/22202015/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/27672743/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/16345993/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9619112/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/19284141/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7957385/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/20104873/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/8798383/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/26396328/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/10895541/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/18007730/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/3763088/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/19284149/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/2506937/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/22202034/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/14248858/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/10054560/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9619126/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/33964219/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/13813431/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/14248866/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/25575624/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9619129/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/24734636/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/10895562/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7521991/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/5860269/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/18007759/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/31026095/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/17187018/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/9619152/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/3763121/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15089869/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/34784975/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/14248889/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15089871/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/5424850/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/3763132/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/8798419/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12151747/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/20104916/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/17187030/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/16346052/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7522005/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/6701274/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/18007762/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/18443210/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/21381339/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/3327700/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/24734669/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/7522008/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/3763150/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12992733/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/15910617/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/31026126/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/12992735/scores/recent?mode=osu&limit=100
# api returned an error of `Too Many Attempts.` for a request to https://osu.ppy.sh/api/v2/users/18007771/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/3763182/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/12151808/scores/recent?mode=osu&limit=100
# 851: 6.394889831542969 18:37:47
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/10486389/scores/recent?mode=osu&limit=100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 18
#      15 for user_ids in partitioned_user_ids:
#      16     print(len(user_ids))
# ---> 18 with ThreadPoolExecutor(max_workers=num_partitions) as executor:
#      19     for user_ids in partitioned_user_ids:
#      20         executor.submit(scrape_users, user_ids)
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File /usr/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/2098078/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/27264018/scores/recent?mode=osu&limit=100
# 1287: 3.3128273487091064 18:38:02
# 1358: 2.6137425899505615 18:38:04
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/13813650/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/10054850/scores/recent?mode=osu&limit=100
# api returned an error of `None` for a request to https://osu.ppy.sh/api/v2/users/5860569/scores/recent?mode=osu&limit=100

# %%
conn.close()

# %% [markdown]
# CREATE TABLE IF NOT EXISTS top_scores_std (
#     user_id INTEGER,
#     beatmap_id INTEGER,
#     beatmapset_id INTEGER,
#     pp INTEGER,
#     mods INTEGER,
#     created_at TEXT
# );
