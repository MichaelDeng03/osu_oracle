# %%
from data_collection import get_beatmaps, get_users, get_user_scores

# %%
from db.orm.models import User
from db import crud
from db.orm import Session

# %%
with Session() as session:
    for id in crud.get_ids(session, User):
        get_user_scores(id)
