# %%
import clr
import sys
from pythonnet import load

clr.AddReference("OsuParsers")

# %%
from OsuParsers.Decoders import BeatmapDecoder

bm = BeatmapDecoder.Decode(
    r"./1011341 Puffy AmiYumi - TEEN TITANS THEME (TV Size) [no video]/Puffy AmiYumi - TEEN TITANS THEME (TV Size) (yShadowXOP_) [Teen Titans GO!].osu"
)

print(bm.MetadataSection.Artist)
# Out:
# Puffy AmiYumi
